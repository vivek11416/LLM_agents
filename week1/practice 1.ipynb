# %%
# imports

import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Constants

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "gemma3"

# %%
# Create a messages list using the same format that we used for OpenAI

messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
# Let's just make sure the model is loaded

# !ollama pull gemma3

# %%
# If this doesn't work for any reason, try the 2 versions in the following cells
# And double check the instructions in the 'Recap on installation of Ollama' at the top of this lab
# And if none of that works - contact me!

response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Okay, let's break down the diverse business applications of Generative AI – it's a rapidly evolving field with huge potential. Here’s a categorized look, with examples and estimated impact levels (Low, Medium, High):
#
# **1. Content Creation & Marketing:**
#
# * **Copywriting & Ad Generation:** (Medium - High) – Tools like Jasper, Copy.ai, and even ChatGPT are being used to generate marketing copy, social media posts, email campaigns, product descriptions, and even full website content. *Impact:* Dramatically reduces content creation time and cost, allows for A/B testing of numerous variations, and personalizes messaging.
# * **Image & Video Generation:** (Medium) – DALL-E 2, Midjourney, Stable Diffusion, and RunwayML are letting businesses create original images and even short videos from text prompts.  This is useful for:
#     * **Product Visualization:** Generating product mockups and lifestyle shots without needing a photographer.
#     * **Social Media Content:**  Creating visually engaging content quickly.
#     * **Explainer Videos:**  Simple animated explainer videos.
# * **Music Generation:** (Low - Medium) – Tools can compose original music tracks in various styles, useful for background music in videos, podcasts, and advertising.
# * **Personalized Content:** (High) – Generative AI can create highly personalized content experiences for customers based on their preferences, behavior, and demographics.
#
#
# **2. Product Development & Innovation:**
#
# * **Design Generation:** (Medium) –  Tools can generate product designs, layouts, and even 3D models based on specified requirements. Useful for:
#     * **Rapid Prototyping:** Quickly exploring different design options.
#     * **Concept Generation:**  Brainstorming new product ideas.
# * **Code Generation:** (High) –  GitHub Copilot, Tabnine, and similar tools assist developers by suggesting code, generating entire functions, and even translating code between languages. *Impact:* Boosts developer productivity, speeds up development cycles, and reduces coding errors.
# * **Drug Discovery & Materials Science:** (High) – Generative AI can predict molecular structures, simulate chemical reactions, and design new materials with specific properties. *Impact:* Accelerates drug development, reduces R&D costs, and leads to breakthroughs in materials science.
#
#
#
# **3. Customer Service & Support:**
#
# * **Chatbots & Virtual Assistants:** (High) –  Generative AI is powering next-generation chatbots that can handle complex customer inquiries, provide personalized support, and even empathize with customers. *Impact:* Reduces the workload on human agents, improves customer satisfaction, and provides 24/7 support.
# * **Personalized Responses:** (Medium) –  Generative AI can tailor responses to individual customer needs and preferences, creating a more engaging and relevant experience.
# * **Summarization of Customer Interactions:** (Medium) – Quickly summarizing lengthy customer support conversations for agents to understand context quickly.
#
# **4. Operations & Productivity:**
#
# * **Meeting Summarization & Action Item Extraction:** (Medium) – Tools like Otter.ai (enhanced with generative AI) can automatically transcribe and summarize meetings, extracting key decisions and action items.
# * **Data Augmentation:** (Medium) – Generative AI can create synthetic data for training machine learning models, especially when real data is scarce or sensitive.
# * **Process Automation:** (Medium) – Generating scripts and workflows for automating repetitive tasks across various departments.
#
#
#
# **5. Finance & Legal:**
#
# * **Fraud Detection:** (High) - Generative AI can identify patterns and anomalies in financial data to predict and prevent fraudulent activities.
# * **Contract Generation & Review:** (Medium) - Assisting in drafting and reviewing legal documents, ensuring accuracy and compliance.
# * **Risk Assessment:** (Medium) –  Generating scenarios and simulations to assess financial risks.
#
#
#
# **Key Considerations & Challenges:**
#
# * **Data Quality:** Generative AI models are only as good as the data they're trained on.  Poor quality data will lead to biased or inaccurate outputs.
# * **Bias & Fairness:**  Careful monitoring and mitigation strategies are needed to address potential biases in AI-generated content.
# * **Hallucinations:**  Generative AI models can sometimes “hallucinate” – that is, generate false or misleading information.  Human oversight is crucial.
# * **Copyright & Intellectual Property:**  The legal implications of using AI-generated content are still evolving.
#
# **Resources for Further Exploration:**
#
# * **OpenAI:** [https://openai.com/](https://openai.com/)
# * **Midjourney:** [https://www.midjourney.com/](https://www.midjourney.com/)
# * **DALL-E 2:** [https://openai.com/dall-e-2/](https://openai.com/dall-e-2/)
# * **GitHub Copilot:** [https://github.com/features/copilot](https://github.com/features/copilot)
#
# To help me give you even more targeted information, could you tell me:
#
# *   What industry are you most interested in (e.g., marketing, manufacturing, healthcare)?
# *   Are you particularly interested in a specific application of generative AI (e.g., content creation, product design, customer service)?

# %% [markdown]
# # ollama package

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
# Okay, let's break down the diverse business applications of Generative AI – it’s rapidly transforming industries! Here’s a categorized overview, with examples:
#
# **1. Content Creation & Marketing:**
#
# * **Copywriting & Ad Generation:** Tools like Jasper.ai, Copy.ai, and others can generate marketing copy for ads, website landing pages, social media posts, email campaigns – even entire blog posts. This dramatically speeds up the creation process and allows for A/B testing of various content variations.
#     * **Example:** A clothing retailer uses Generative AI to create 10 different ad variations for a new summer collection, targeting different demographics and styles.
# * **Image & Video Generation:** DALL-E 2, Midjourney, Stable Diffusion, and others let businesses create unique images and videos from text prompts.  This is great for:
#     * **Product Visualization:** Generating realistic images of products in different settings, even in conceptual designs.
#     * **Social Media Content:** Quickly creating engaging visuals for social media marketing.
#     * **Explainer Videos:**  Generating short animated videos to explain complex concepts.
# * **Personalized Content:** Generative AI can tailor content to individual customer preferences, improving engagement and conversion rates.
#     * **Example:**  An e-commerce site uses AI to generate product descriptions that highlight features a customer has previously shown interest in.
#
#
# **2. Product Development & Design:**
#
# * **Design Ideation & Concept Generation:**  AI can generate dozens of design concepts based on specified parameters (e.g., “minimalist chair for a modern office”).
# * **3D Modeling & Prototyping:** Emerging tools are starting to leverage generative AI to help create 3D models and rapid prototypes, especially in areas like automotive and aerospace.
# * **Drug Discovery & Material Science:**  AI is accelerating the development of new drugs and materials by generating molecular structures and predicting their properties.  (This is a high-investment area).
# * **Code Generation:** Tools like GitHub Copilot use generative AI to suggest code snippets, complete functions, and even generate entire code blocks based on natural language prompts.
#
# **3. Customer Service & Support:**
#
# * **Chatbots & Virtual Assistants:**  Generative AI is powering more sophisticated chatbots that can understand and respond to complex customer queries, going beyond simple scripted responses.
# * **Personalized Support Responses:** AI can tailor support responses based on the customer's history, sentiment, and the specific issue they’re facing.
# * **Summarizing Customer Interactions:**  AI can quickly summarize lengthy customer support conversations, allowing agents to quickly understand the context of an issue.
#
# **4. Operations & Efficiency:**
#
# * **Report Generation:**  AI can automatically generate reports from data, providing insights and recommendations.
# * **Process Automation:**  Generative AI can be used to create custom workflows and automate repetitive tasks.
# * **Data Augmentation:**  In areas like training machine learning models, Generative AI can create synthetic data to supplement real data, particularly useful when real data is scarce or sensitive.
#
#
# **5.  Finance & Legal:**
#
# * **Contract Review & Generation:** AI can review legal documents, identify potential risks, and even draft basic contracts. (Requires careful oversight and validation).
# * **Fraud Detection:**  Generative AI can identify unusual patterns in financial data that may indicate fraudulent activity.
# * **Financial Modeling & Forecasting:**  AI can generate financial models and forecasts based on various scenarios.
#
#
#
# **Important Considerations & Current Limitations:**
#
# * **Accuracy & Hallucinations:** Generative AI models can sometimes produce inaccurate or misleading information (known as "hallucinations"). Human oversight is crucial.
# * **Bias:**  AI models can reflect biases present in the data they were trained on.  Careful evaluation and mitigation strategies are necessary.
# * **Cost:** Implementing and using Generative AI tools can be expensive, especially for sophisticated applications.
# * **Copyright & Intellectual Property:** The use of Generative AI raises complex questions about copyright and ownership of generated content.
#
# **Resources for Further Exploration:**
#
# * **OpenAI:** [https://openai.com/](https://openai.com/)
# * **Jasper.ai:** [https://www.jasper.ai/](https://www.jasper.ai/)
# * **Midjourney:** [https://www.midjourney.com/](https://www.midjourney.com/)
# * **GitHub Copilot:** [https://github.com/features/copilot](https://github.com/features/copilot)
#
#
# Do you want me to delve deeper into a specific application area, like Generative AI for marketing, or perhaps explore a particular tool?

# %%
# There's actually an alternative approach that some people might prefer
# You can use the OpenAI client python library to call Ollama:

from openai import OpenAI
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

response = ollama_via_openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Okay, let's break down the business applications of Generative AI – it’s a rapidly evolving field with huge potential. Here's a categorized look at how companies are already using it, with examples and levels of maturity:
#
# **1. Content Creation & Marketing:**
#
# * **Text Generation (Most Mature):**
#     * **Copywriting & Ad Creation:** Tools like Jasper, Copy.ai, and even ChatGPT are being used to generate marketing copy for ads, emails, website content, product descriptions, and social media posts. *Companies using it:* Many e-commerce brands, marketing agencies.
#     * **Blog Post & Article Generation:**  Drafting early drafts of blog posts and articles, freeing up writers to focus on editing and strategy. *Companies Using it:*  News outlets, content marketing teams.
#     * **Email Campaigns:** Personalized email sequences, subject lines, and even entire email content. *Companies Using it:*  Sales teams, lead nurturing programs.
#     * **Product Descriptions:** Automating the creation of rich product descriptions for e-commerce. *Companies Using it:*  Amazon, Shopify stores.
# * **Image/Video Generation (Rapidly Growing):**
#    * **Stock Images/Videos:** Generating unique stock photos and videos based on text prompts – reducing reliance on traditional stock photo sites. *Companies Using it:*  Brands needing visual content, small businesses. (Tools like DALL-E 2, Midjourney, Stable Diffusion)
#    * **Social Media Visuals:** Creating engaging visuals for social media campaigns quickly and cost-effectively. *Companies Using it:*  Brands with heavy social media presence.
#    * **Concept Art & Design Mockups:** Quickly generating visual concepts for products or marketing materials. *Companies Using it:*  Design firms, product development.
#
#
#
# **2. Product Development & Innovation:**
#
# * **Brainstorming & Idea Generation:**  AI can generate numerous ideas for new products, features, or marketing campaigns based on given inputs (market trends, competitor analysis, customer feedback). *Companies Using it:*  Tech companies, product management teams.
# * **Code Generation:** AI tools (like GitHub Copilot) can suggest code snippets, complete code blocks, and even generate entire functions based on natural language descriptions—significantly boosting developer productivity. *Companies Using it:*  Software development companies, startups.
# * **Design Optimization:** Generative AI can explore different design variations for products, considering factors like ergonomics, aesthetics, and manufacturing constraints. *Companies Using it:*  Engineering firms, automotive manufacturers.
# * **Drug Discovery:** AI is being used to generate novel molecules with desired properties, accelerating the drug development process. *Companies Using it:*  Pharmaceutical companies, biotech firms.
#
#
# **3. Customer Service & Support:**
#
# * **Chatbots & Virtual Assistants:**  Advanced chatbots (powered by models like GPT-4) can handle complex customer inquiries, provide personalized support, and even resolve issues without human intervention. *Companies Using it:*  E-commerce companies, financial institutions.
# * **Personalized Recommendations:**  Generating tailored product or service recommendations based on individual customer preferences and behavior. *Companies Using it:*  E-commerce, streaming services.
# * **Summarizing Customer Interactions:** Quickly summarizing lengthy customer support conversations for agents to quickly understand the context. *Companies Using it:*  Call centers, helpdesk systems.
#
#
# **4. Operations & Administration:**
#
# * **Report Generation:** Automatically creating reports based on data analysis, saving time and resources. *Companies Using it:*  Financial institutions, marketing analytics teams.
# * **Meeting Summarization & Transcription:** Automatically transcribing and summarizing meetings, improving productivity and knowledge sharing. *Companies Using it:*  Large corporations, consulting firms.
# * **Data Augmentation:** Generating synthetic data to train machine learning models, especially useful when real-world data is scarce. *Companies Using it:*  AI/ML development teams, research institutions.
#
#
#
# **Levels of Maturity & Key Considerations:**
#
# * **Early Adoption (High Maturity):** Text generation for copywriting and basic chatbot applications.
# * **Mid-Stage (Growing Maturity):** Image generation, more sophisticated chatbot applications, and code generation.
# * **Early Stage (Lower Maturity):**  More complex applications like drug discovery and highly specialized design optimization. Requires significant research and development.
#
# **Important Notes:**
#
# * **Accuracy & Bias:** Generative AI models can sometimes produce inaccurate or biased outputs. Human oversight and careful validation are crucial.
# * **Cost:**  Accessing and utilizing these tools can be expensive, particularly for complex applications.
# * **IP & Copyright:**  The legal implications of using AI-generated content are still being explored.
#
#
#
# To help me give you even more targeted information, could you tell me:
#
# *   What industry are you most interested in (e.g., marketing, healthcare, finance, manufacturing)?
# *   Are there specific business challenges you're hoping to address with generative AI?

# %% [markdown]
# ## DeepSeek

# %%
# !ollama pull deepseek-r1:1.5b

# %%
# This may take a few minutes to run! You should then see a fascinating "thinking" trace inside <think> tags, followed by some decent definitions

response = ollama_via_openai.chat.completions.create(
    model="deepseek-r1:1.5b",
    messages=[{"role": "user", "content": "Please give definitions of some core concepts behind LLMs: a neural network, attention and the transformer"}]
)

print(response.choices[0].message.content)
# Out:
# <think>
# Okay, so I need to figure out the core concepts related to Large Language Models (LLMs) that are based on both Neural Networks and Transformers. Hmm, where do I start? Let me think.
#
# First off, the question is asking for definitions of terms behind LLMs, specifically focusing on neural networks and transformers. So, probably these terms will be more specific within the context of what's used in LLMs. I remember that large language models are trained using big datasets, so maybe data plays a role there.
#
# Starting with the neural network aspect. Neural networks, as I kinda understand aren't just any AI; they have layered structures. So, perhaps it's about how a multilayer perceptron fits into this? Also, if LLMs use deep learning, that involves multiple layers of neurons processing information. Maybe each layer in an MLP processes different aspects or levels of the data. That could relate to understanding how context or semantics are being captured.
#
# But wait, the user mentioned "core concepts." So maybe I should think about specific components like input sequences for attention mechanisms or embedding representations? How do these inputs get transformed through layers?
#
# Next, transformers and attention. Transformers seem different from standard neural networks though. They might use something called self-attention. I've heard that each layer in a transformer can process the entire sequence at once using a set of learnable parameters. So, each token in the input looks back for all relevant positions to compute its embedding.
#
# Wait, but how does this tie into LLMs? If each position is processed independently with attention across the entire sequence, maybe that's similar to convolutional neural networks where each patch processes information based on others. But probably more sophisticated because it scales with the input size.
#
# Also, token-wise processing in transformers—each token has an embedding and a context vector. The context vectors are computed as a weighted sum of all tokens' embeddings through matrix multiplication with a learnable weight matrix. So that must be part of how the model learns representations for each word at every position.
#
# Putting it together: In LLMs, big models have their parameters (like MLPs in another sense) and then transformers handle sequence dependencies via self-attention mechanisms. That sounds familiar from what I remember about models like BERT or GPT-3.
#
# Wait, just to make sure—MLPs are used for non-linearities and feature transformations. So maybe the neural network part of LLMs is more about the structure of the model's components rather than standard machine learning algorithms. But they still are similar because their operations have specific structures (like multi-layer perceptrons).
#
# And then transformers specifically use self-attention to capture attention over sequences, which might be a higher-level component than the typical layers in neural networks.
#
# So, to summarize my thoughts: LLMs use multilayer perceptron layers for general tasks and transformers with self-attention mechanisms for modeling long-range dependencies. Both are essential for capturing complex language patterns.
# </think>
#
# Large Language Models (LLMs), such as BERT or GPT-3, integrate neural networks and Transformers to enable the learning of complex language patterns. Here's a structured overview:
#
# 1. **Neural Networks in LLMs**:
#    - **Deep Learning Structure**: LLMs employ multilayer perceptrons (MLPs) for processing sequential data, which allows them to learn hierarchical representations from sequences.
#    - **Context and Semantics**: MLPs help capture context and semantic information by transforming input sequences through layers that process different levels of the data.
#
# 2. **Transformers in LLMs**:
#    - **Self-Attention Mechanism**: Transformers utilize self-attention, where each token processes others across the entire sequence via learnable weights, allowing it to model long-range dependencies.
#    - **Positional Embeddings**: Computed from embeddings of tokens and context vectors, these embed every position in the input, enhancing representational learning.
#
# 3. **Core Concepts**:
#    - **MLPs as Neural Networks**: Process sequential data through layers that capture feature transformations and nonlinearities.
#    - **Transformers with Self-Attention**: Use self-attention to enable sequence-dependent processing, making them computationally intensive yet efficient for capturing diverse language patterns.
#
# In essence, LLMs leverage a combination of MLPs for general language understanding and Transformers' self-attention mechanisms to model long-range dependencies. Together, these components enable the models to learn nuanced representations from text data effectively.
